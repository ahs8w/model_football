# %% [markdown]
# ### projection model => project points per player
# - [ ]    Basic Stats
# - [ ]    Usage
# - [ ]    Percentage of team scoring
# - [ ]    Injuries
# - [ ]    Bye week
# - [ ]    Injuries to Key Teammates
# - [ ]    Individual Matchups
# - [ ]    Opposing Team (record, defense, injuries, etc.)
# - [ ]    Home/Away
# - [ ]    Weather
# - [ ]    Expert Picks
# - [x]    Other Fantasy Projections
#
# ### selection mechanism => choose optimal team within parameters
# - [ ]    maximize value (pts/salary)
# - [x]    Linear Optimization
#     - Inspiration: https://github.com/breeko/Fantasy_LP/blob/master/fantasy_lp_final.ipynb

# %%
import pandas as pd
# from matplotlib import pyplot as plt
import numpy as np

# %%
year = 2024
week = 8

# %% [markdown]
# # This Week

# %%
primary_dir = f"/Users/adamschiller/OneDrive - BOOZ ALLEN HAMILTON/Fantasy Football/{year}"
sal_dir = f"{primary_dir}/Weekly Salary Data"

# %% [markdown]
# ## Rotowire

# %%
# https://www.rotowire.com/daily/nfl/dfs-opportunities.php?site=DraftKings  # choose full slate
def rotowire_csv(filepath):
    df = pd.read_csv(filepath)
    df.rename(columns={'PLAYER': 'name', 'POS': 'pos', 'SAL': 'salary', 'FPTS': 'prediction'}, inplace=True)
    df.loc[df['pos']=='D', 'pos'] = 'Def'
    df = df[['name','pos','salary','prediction']]
    return df
    
rdf = rotowire_csv(f"{sal_dir}/week{week}_rotowire-NFL-projected-roster-percent.csv")
rdf
# Out:
#                     name pos  salary  prediction
# 0         Justin Herbert  QB    5400       16.11
# 1                 Bo Nix  QB    5600       16.65
# 2       Matthew Stafford  QB    5500       15.80
# 3         Jalen McMillan  WR    3700       10.72
# 4            Brock Purdy  QB    6300       18.14
# ..                   ...  ..     ...         ...
# 599        Colton Dowell  WR    3000        0.00
# 600            Tyler Ott  TE    2500        0.00
# 601         Sam Ehlinger  QB    4000        0.00
# 602       Brayden Willis  TE    2500        0.00
# 603  Christian McCaffrey  RB    8000        0.00
#
# [604 rows x 4 columns]

# %%
len(rdf[rdf['pos']=='Def'])
# Out:
# 32

# %% [markdown]
# ## Antonio's Official Data

# %%
df = pd.read_csv(f"{sal_dir}/week{week}_salaries.csv")

def format_antonio_salary_data(df):
    df.rename(columns={'PLAYER': 'name', 'SAL': 'salary', 'FPTS': 'prediction', 'POS': 'pos'}, inplace=True)
    # df.loc[df['pos']=='DST', 'pos'] = 'Def'
    df.loc[df['pos']=='D', 'pos'] = 'Def'
    df = df[['name','pos','salary','prediction']]
    return df

adf = format_antonio_salary_data(df)
adf
# Out:
#                     name pos  salary  prediction
# 0         Justin Herbert  QB    5400       16.11
# 1                 Bo Nix  QB    5600       16.79
# 2       Matthew Stafford  QB    5500       15.74
# 3         Jalen McMillan  WR    3700       10.72
# 4            Brock Purdy  QB    6300       18.21
# ..                   ...  ..     ...         ...
# 597       Brayden Willis  TE    2500        0.00
# 598        Rondale Moore  WR    3000        0.00
# 599         Clayton Tune  QB    4400        0.00
# 600      Elijah Mitchell  RB    4000        0.00
# 601  Christian McCaffrey  RB    8000        0.00
#
# [602 rows x 4 columns]

# %%
len(adf[adf['pos']=='Def'])
# Out:
# 32

# %% [markdown]
# ## Daily Fantasy Fuel

# %%
# map defense names for dff based on rotowire names
def defense_mapping(df):
    return {n.split(' ')[-1]: n for n in df[df['pos']=='Def']['name']}

defense_map = defense_mapping(adf)

def apply_defense_map(x):
    try:
        return defense_map[x]
    except KeyError:
        return x

# %%
# https://www.dailyfantasyfuel.com/nfl?platform=dk&slate=1C369
# https://www.dailyfantasyfuel.com/nfl/projections/
def dff_csv(filepath):
    df = pd.read_csv(filepath)
    df['name'] = df['first_name']+' '+df['last_name']
    df.rename(columns={'position': 'pos', 'ppg_projection': 'prediction'}, inplace=True)
    # fix names for defenses based on mapping created by rotowire data above
    df.loc[df['pos']=='DST', 'name'] = df['first_name'].apply(lambda x: apply_defense_map(x))
    df.loc[df['pos']=='DST', 'pos'] = 'Def'
    df = df[['name','pos','injury_status','salary','prediction']]
    return df

dff = dff_csv(f"{sal_dir}/week{week}_DFF_NFL_cheatsheet.csv")
dff
# Out:
#                     name pos injury_status  salary  prediction
# 0          Lamar Jackson  QB           NaN    8000        22.6
# 1            Breece Hall  RB           NaN    7300        21.5
# 2             Josh Allen  QB           NaN    7800        20.7
# 3            Jalen Hurts  QB           NaN    7500        20.3
# 4       Justin Jefferson  WR           NaN    8800        19.8
# ..                   ...  ..           ...     ...         ...
# 428  JuJu Smith-Schuster  WR             O    4500         0.0
# 429        Michael Mayer  TE             O    2500         0.0
# 430        Jordan Travis  QB             O    4000         0.0
# 431           Mike Evans  WR             O    7300         0.0
# 432         Robert Burns  RB             O    4000         0.0
#
# [433 rows x 5 columns]

# %%
len(dff[dff['pos']=='Def'])
# Out:
# 32

# %% [markdown]
# ## Merge sources

# %%
def merge_sources(df1, df2):
    df = df1.merge(df2[['name','injury_status','prediction']], on='name', how='inner', suffixes=('_df1', '_df2'))
    df = df[df['injury_status'].isna()]
    df = df[(df['prediction_df1']>0)&(df['prediction_df2']>0)]
    df['prediction'] = df[['prediction_df1', 'prediction_df2']].mean(axis=1)
    df['pred_diff'] = abs(df['prediction_df1']-df['prediction_df2'])
    df.drop(columns=['injury_status'], inplace=True)  #,'prediction_df1','prediction_df2'
    return df

# %%
df = merge_sources(adf, dff)
df
# Out:
#                   name pos  salary  prediction_df1  prediction_df2  \
# 0       Justin Herbert  QB    5400           16.11            16.2
# 1               Bo Nix  QB    5600           16.79            19.3
# 2     Matthew Stafford  QB    5500           15.74            15.7
# 3       Jalen McMillan  WR    3700           10.72            10.4
# 4          Brock Purdy  QB    6300           18.21            18.7
# ..                 ...  ..     ...             ...             ...
# 383       Eric Saubert  TE    2500            0.26             0.5
# 385     Kenny McIntosh  RB    4000            0.52             0.6
# 386       Will Shipley  RB    4000            0.54             0.5
# 389      Cody Schrader  RB    4000            0.17             0.2
# 398  Israel Abanikanda  RB    4000            0.16             0.2
#
#      prediction  pred_diff
# 0        16.155       0.09
# 1        18.045       2.51
# 2        15.720       0.04
# 3        10.560       0.32
# 4        18.455       0.49
# ..          ...        ...
# 383       0.380       0.24
# 385       0.560       0.08
# 386       0.520       0.04
# 389       0.185       0.03
# 398       0.180       0.04
#
# [334 rows x 7 columns]

# %%
df.sort_values('pred_diff', ascending=False)
# Out:
#                   name  pos  salary  prediction_df1  prediction_df2  \
# 156       Tony Pollard   RB    6500           12.16            18.4
# 151       J.K. Dobbins   RB    6900           13.33            19.2
# 354      Tyler Goodson   RB    5500            0.85             6.7
# 240      Kalif Raymond   WR    3400            3.79             8.2
# 179       Najee Harris   RB    6100           10.25            14.5
# ..                 ...  ...     ...             ...             ...
# 223   Devin Singletary   RB    5900            7.39             7.4
# 280         Ian Thomas   TE    2500            1.39             1.4
# 68    Seattle Seahawks  Def    2500            5.41             5.4
# 305      Durham Smythe   TE    2600            1.40             1.4
# 145  Arizona Cardinals  Def    2900            5.60             5.6
#
#      prediction  pred_diff
# 156      15.280       6.24
# 151      16.265       5.87
# 354       3.775       5.85
# 240       5.995       4.41
# 179      12.375       4.25
# ..          ...        ...
# 223       7.395       0.01
# 280       1.395       0.01
# 68        5.405       0.01
# 305       1.400       0.00
# 145       5.600       0.00
#
# [334 rows x 7 columns]

# %%
df['pos'].value_counts()
# Out:
# pos
# WR     117
# RB      88
# TE      71
# Def     32
# QB      26
# Name: count, dtype: int64

# %% [markdown]
# # Top Projected per Pos

# %%
def avg_per_dollar(df, col):
    df['Avg Value'] = df[col] / (df['salary'] / 1000)
    return df.sort_values('Avg Value', ascending=False)

pdf = avg_per_dollar(df, 'prediction')

# %%
top_QBs = pdf[pdf.pos=='QB']
top_QBs.head(5)
# Out:
#               name pos  salary  prediction_rdf  prediction_dff  prediction  \
# 82    Joshua Dobbs  QB    5900           15.34            27.5      21.420
# 76   Justin Fields  QB    7000           19.03            29.3      24.165
# 1     Dak Prescott  QB    6800           20.69            22.5      21.595
# 0      Brock Purdy  QB    6100           18.51            19.0      18.755
# 70  Baker Mayfield  QB    5500           16.15            16.3      16.225
#
#     pred_diff  Avg Value
# 82      12.16   3.630508
# 76      10.27   3.452143
# 1        1.81   3.175735
# 0        0.49   3.074590
# 70       0.15   2.950000

# %%
top_RBs = pdf[pdf.pos=='RB']
top_RBs.head(5)
# Out:
#                     name pos  salary  prediction_rdf  prediction_dff  \
# 2        Zach Charbonnet  RB    5300           14.81            14.0
# 9    Christian McCaffrey  RB    8700           20.70            23.6
# 8           Tony Pollard  RB    6700           16.36            16.3
# 103        Rachaad White  RB    6100           13.99            15.7
# 197       Khalil Herbert  RB    5100            9.54            14.8
#
#      prediction  pred_diff  Avg Value
# 2        14.405       0.81   2.717925
# 9        22.150       2.90   2.545977
# 8        16.330       0.06   2.437313
# 103      14.845       1.71   2.433607
# 197      12.170       5.26   2.386275

# %%
top_WRs = pdf[pdf.pos=='WR']
top_WRs.head(5)
# Out:
#                name pos  salary  prediction_rdf  prediction_dff  prediction  \
# 126        DJ Moore  WR    6000           13.34            21.1       17.22
# 81     Drake London  WR    5000           12.82            13.1       12.96
# 79   Rashid Shaheed  WR    4300           11.38            10.7       11.04
# 145  Jordan Addison  WR    5700           11.80            16.8       14.30
# 18      CeeDee Lamb  WR    8700           19.44            23.5       21.47
#
#      pred_diff  Avg Value
# 126       7.76   2.870000
# 81        0.28   2.592000
# 79        0.68   2.567442
# 145       5.00   2.508772
# 18        4.06   2.467816

# %%
top_TEs = pdf[pdf.pos=='TE']
top_TEs.head(5)
# Out:
#                name pos  salary  prediction_rdf  prediction_dff  prediction  \
# 7     Jake Ferguson  TE    3900            9.69            10.9      10.295
# 85      Evan Engram  TE    4200           10.66            11.1      10.880
# 102  T.J. Hockenson  TE    5800           13.45            14.5      13.975
# 14     Logan Thomas  TE    3500            7.99             8.2       8.095
# 164    Trey McBride  TE    4700            9.24            12.4      10.820
#
#      pred_diff  Avg Value
# 7         1.21   2.639744
# 85        0.44   2.590476
# 102       1.05   2.409483
# 14        0.21   2.312857
# 164       3.16   2.302128

# %%
# players[players.Pos == 'Def'].head(3)
top_Defs = pdf[pdf.pos=='Def']
top_Defs.head(5)
# Out:
#                      name  pos  salary  prediction_rdf  prediction_dff  \
# 83     Kansas City Chiefs  Def    3100            8.18             8.7
# 115        Miami Dolphins  Def    3500            8.01             9.7
# 99         Denver Broncos  Def    3200            7.72             8.4
# 95      Minnesota Vikings  Def    3200            7.67             7.8
# 92   New England Patriots  Def    3200            7.61             7.7
#
#      prediction  pred_diff  Avg Value
# 83        8.440       0.52   2.722581
# 115       8.855       1.69   2.530000
# 99        8.060       0.68   2.518750
# 95        7.735       0.13   2.417187
# 92        7.655       0.09   2.392187

# %% [markdown]
# # Team Selection

# %% [markdown]
# $$\begin{aligned}
# objective &= maximize\ team\ points \\
# team\ salary &\leq salary\ cap \\
# team &= 1\ QB + (2|3)\ RB + (3|4)\ WR + (1|2)\ TE + 1\ DEF \\
# team &\leq 9\ total\ players \\
# \end{aligned}$$

# %%
# %pip install pulp

# %%
from pulp import *

class PulpSelection():
    def __init__(self, df, pts_col="prediction", sal_col="salary", name_col="name", salary_cap=50000):
        self.df = df
        self.vars = self.populate_vars(pts_col, sal_col, name_col)
        self.model = self.optimize(salary_cap)
        self.players = self.player_names()
        self.selection = self.selection_df()
        
    def populate_vars(self, pts_col, sal_col, name_col):
        df = self.df
        salaries = {}
        points = {}
        for pos in df.pos.unique():
            available_pos = df[df.pos == pos]
            salary = list(available_pos[[name_col,sal_col]].set_index(name_col).to_dict().values())[0]
            point = list(available_pos[[name_col,pts_col]].set_index(name_col).to_dict().values())[0]
            salaries[pos] = salary
            points[pos] = point
            
        self.salaries = salaries
        self.points = points
        return {k: LpVariable.dict(k, v, cat="Binary") for k, v in points.items()}

    def player_names(self):
        players = {}
        for d in self.vars.values():
            for k,v in d.items():
                players[v] = k
        return players
            
    pos_num_available = {
        "QB": 1,
        "RB": 2,
        "WR": 3,
        "TE": 1,
        "Def": 1
    }

    def optimize(self, salary_cap):
        prob = LpProblem("FFModel", LpMaximize)
        rewards = []
        costs = []

        for pos, players in self.vars.items():
            costs += lpSum([self.salaries[pos][i] * self.vars[pos][i] for i in players])
            rewards += lpSum([self.points[pos][i] * self.vars[pos][i] for i in players])
            if pos in ['RB','WR','TE']:
                prob += lpSum([self.vars[pos][i] for i in players]) <= self.pos_num_available[pos]+1
                prob += lpSum([self.vars[pos][i] for i in players]) >= self.pos_num_available[pos]
            else:
                prob += lpSum([self.vars[pos][i] for i in players]) == self.pos_num_available[pos]
        prob += lpSum(prob.variables()) == 9    # flex -> max of 9 total players

        prob += lpSum(rewards)
        prob += lpSum(costs) <= salary_cap
        print(prob.solve())
        return prob
    
    def selection_df(self):
        selections = [self.players[p] for p in self.model.variables() if p.varValue > 0]
        team = self.df[self.df.name.isin(selections)]
        return team

# %%
pts_col = 'prediction'
model = PulpSelection(df, pts_col=pts_col)
team = model.selection
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/adamschiller/bah_projects/model_football/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/pl/yvv0vk397x34b_lzgcmsd43w0000gp/T/1b99aa2416814e108301053b7f48aa81-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/pl/yvv0vk397x34b_lzgcmsd43w0000gp/T/1b99aa2416814e108301053b7f48aa81-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 2296 RHS
# At line 2307 BOUNDS
# At line 2642 ENDATA
# Problem MODEL has 10 rows, 334 columns and 1278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 133.152 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 314 columns (314 integer (313 of which binary)) and 942 elements
# Cutoff increment increased from 1e-05 to 0.004995
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.210526
# Cbc0038I Pass   1: suminf.    0.24242 (2) obj. -131.599 iterations 5
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. -114.52 iterations 3
# Cbc0038I Solution found of -114.52
# Cbc0038I Cleaned solution of -114.52
# Cbc0038I Before mini branch and bound, 310 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 314 columns, reduced to 4 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -114.52 to -126.33 (0.01 seconds)
# Cbc0038I Round again with cutoff of -127.017
# Cbc0038I Reduced cost fixing fixed 118 variables on major pass 2
# Cbc0038I Pass   3: suminf.    0.16667 (2) obj. -132.45 iterations 1
# Cbc0038I Pass   4: suminf.    0.76836 (2) obj. -127.017 iterations 7
# Cbc0038I Pass   5: suminf.    0.97108 (4) obj. -127.017 iterations 15
# Cbc0038I Pass   6: suminf.    0.33818 (4) obj. -127.017 iterations 6
# Cbc0038I Pass   7: suminf.    0.46111 (4) obj. -127.017 iterations 6
# Cbc0038I Pass   8: suminf.    0.25000 (2) obj. -127.193 iterations 3
# Cbc0038I Pass   9: suminf.    0.26946 (2) obj. -127.017 iterations 4
# Cbc0038I Pass  10: suminf.    1.44549 (4) obj. -127.017 iterations 10
# Cbc0038I Pass  11: suminf.    0.77943 (4) obj. -127.017 iterations 5
# Cbc0038I Pass  12: suminf.    0.09479 (2) obj. -127.017 iterations 9
# Cbc0038I Pass  13: suminf.    0.09479 (2) obj. -127.017 iterations 2
# Cbc0038I Pass  14: suminf.    1.00000 (3) obj. -127.017 iterations 7
# Cbc0038I Pass  15: suminf.    1.00000 (3) obj. -127.017 iterations 8
# Cbc0038I Pass  16: suminf.    0.17803 (2) obj. -127.017 iterations 4
# Cbc0038I Solution found of -127.975
# Cbc0038I Cleaned solution of -127.975
# Cbc0038I Before mini branch and bound, 290 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 314 columns, reduced to 5 rows 20 columns
# Cbc0038I Mini branch and bound improved solution from -127.975 to -132.09 (0.02 seconds)
# Cbc0038I Round again with cutoff of -132.306
# Cbc0038I Reduced cost fixing fixed 276 variables on major pass 3
# Cbc0038I Pass  17: suminf.    0.21053 (2) obj. -133.152 iterations 4
# Cbc0038I Pass  18: suminf.    0.75749 (2) obj. -132.306 iterations 5
# Cbc0038I Pass  19: suminf.    0.65306 (2) obj. -132.815 iterations 4
# Cbc0038I Pass  20: suminf.    0.75907 (2) obj. -132.306 iterations 3
# Cbc0038I Pass  21: suminf.    1.03938 (4) obj. -132.306 iterations 9
# Cbc0038I Pass  22: suminf.    0.81633 (2) obj. -132.612 iterations 3
# Cbc0038I Pass  23: suminf.    0.87990 (2) obj. -132.306 iterations 2
# Cbc0038I Pass  24: suminf.    1.13835 (4) obj. -132.306 iterations 2
# Cbc0038I Pass  25: suminf.    1.13835 (4) obj. -132.306 iterations 0
# Cbc0038I Pass  26: suminf.    0.42105 (2) obj. -132.93 iterations 3
# Cbc0038I Pass  27: suminf.    0.87807 (2) obj. -132.306 iterations 3
# Cbc0038I Pass  28: suminf.    0.81633 (2) obj. -132.612 iterations 3
# Cbc0038I Pass  29: suminf.    0.87990 (2) obj. -132.306 iterations 2
# Cbc0038I Pass  30: suminf.    0.96177 (3) obj. -132.306 iterations 3
# Cbc0038I Pass  31: suminf.    0.96177 (3) obj. -132.306 iterations 1
# Cbc0038I Pass  32: suminf.    0.65306 (2) obj. -132.815 iterations 2
# Cbc0038I Pass  33: suminf.    0.65306 (2) obj. -132.815 iterations 1
# Cbc0038I Pass  34: suminf.    0.75907 (2) obj. -132.306 iterations 2
# Cbc0038I Pass  35: suminf.    0.60571 (4) obj. -132.306 iterations 3
# Cbc0038I Pass  36: suminf.    0.44054 (3) obj. -132.306 iterations 1
# Cbc0038I Pass  37: suminf.    0.52632 (2) obj. -132.477 iterations 3
# Cbc0038I Pass  38: suminf.    0.38180 (2) obj. -132.306 iterations 2
# Cbc0038I Pass  39: suminf.    0.98457 (3) obj. -132.306 iterations 2
# Cbc0038I Pass  40: suminf.    1.38453 (4) obj. -132.306 iterations 7
# Cbc0038I Solution found of -132.425
# Cbc0038I Cleaned solution of -132.425
# Cbc0038I Before mini branch and bound, 299 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 314 columns, reduced to 4 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -132.647
# Cbc0038I Reduced cost fixing fixed 291 variables on major pass 4
# Cbc0038I Pass  41: suminf.    0.21053 (2) obj. -133.152 iterations 0
# Cbc0038I Pass  42: suminf.    0.68676 (2) obj. -132.647 iterations 6
# Cbc0038I Pass  43: suminf.    0.65306 (2) obj. -132.815 iterations 4
# Cbc0038I Pass  44: suminf.    0.68819 (2) obj. -132.647 iterations 3
# Cbc0038I Pass  45: suminf.    1.00000 (3) obj. -132.647 iterations 6
# Cbc0038I Pass  46: suminf.    1.00000 (3) obj. -132.647 iterations 3
# Cbc0038I Pass  47: suminf.    0.16655 (2) obj. -132.647 iterations 2
# Cbc0038I Pass  48: suminf.    0.10526 (2) obj. -132.879 iterations 3
# Cbc0038I Pass  49: suminf.    0.87634 (3) obj. -132.647 iterations 4
# Cbc0038I Pass  50: suminf.    0.87634 (3) obj. -132.647 iterations 1
# Cbc0038I Pass  51: suminf.    0.22557 (2) obj. -132.647 iterations 5
# Cbc0038I Pass  52: suminf.    0.19780 (2) obj. -132.647 iterations 4
# Cbc0038I Pass  53: suminf.    0.11111 (2) obj. -132.951 iterations 2
# Cbc0038I Pass  54: suminf.    0.68676 (2) obj. -132.647 iterations 4
# Cbc0038I Pass  55: suminf.    0.65306 (2) obj. -132.815 iterations 4
# Cbc0038I Pass  56: suminf.    0.68819 (2) obj. -132.647 iterations 3
# Cbc0038I Pass  57: suminf.    0.76245 (3) obj. -132.647 iterations 5
# Cbc0038I Pass  58: suminf.    0.76245 (3) obj. -132.647 iterations 0
# Cbc0038I Pass  59: suminf.    0.88372 (2) obj. -132.711 iterations 5
# Cbc0038I Pass  60: suminf.    0.88372 (2) obj. -132.711 iterations 0
# Cbc0038I Pass  61: suminf.    1.00000 (3) obj. -132.647 iterations 4
# Cbc0038I Pass  62: suminf.    0.67456 (3) obj. -132.647 iterations 5
# Cbc0038I Pass  63: suminf.    0.36842 (2) obj. -132.845 iterations 4
# Cbc0038I Pass  64: suminf.    1.00000 (3) obj. -132.647 iterations 3
# Cbc0038I Pass  65: suminf.    1.00000 (3) obj. -132.647 iterations 3
# Cbc0038I Pass  66: suminf.    0.48844 (2) obj. -132.647 iterations 2
# Cbc0038I Pass  67: suminf.    0.34406 (2) obj. -132.647 iterations 4
# Cbc0038I Pass  68: suminf.    0.31579 (2) obj. -132.751 iterations 3
# Cbc0038I Pass  69: suminf.    0.98083 (3) obj. -132.647 iterations 3
# Cbc0038I Pass  70: suminf.    0.74593 (3) obj. -132.647 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 303 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 314 columns, reduced to 4 rows 9 columns
# Cbc0038I Mini branch and bound improved solution from -132.425 to -132.665 (0.03 seconds)
# Cbc0038I Round again with cutoff of -132.815
# Cbc0038I Reduced cost fixing fixed 295 variables on major pass 5
# Cbc0038I Pass  70: suminf.    0.21053 (2) obj. -133.152 iterations 0
# Cbc0038I Pass  71: suminf.    0.29909 (2) obj. -132.815 iterations 4
# Cbc0038I Pass  72: suminf.    0.50942 (2) obj. -132.815 iterations 5
# Cbc0038I Pass  73: suminf.    0.28342 (2) obj. -132.815 iterations 2
# Cbc0038I Pass  74: suminf.    0.77295 (3) obj. -132.815 iterations 5
# Cbc0038I Pass  75: suminf.    0.97960 (2) obj. -132.815 iterations 4
# Cbc0038I Pass  76: suminf.    0.97960 (2) obj. -132.815 iterations 0
# Cbc0038I Pass  77: suminf.    0.95028 (3) obj. -132.815 iterations 4
# Cbc0038I Pass  78: suminf.    1.15191 (4) obj. -132.815 iterations 5
# Cbc0038I Pass  79: suminf.    0.80264 (3) obj. -132.815 iterations 2
# Cbc0038I Pass  80: suminf.    0.36842 (2) obj. -132.816 iterations 4
# Cbc0038I Pass  81: suminf.    0.36842 (2) obj. -132.816 iterations 0
# Cbc0038I Pass  82: suminf.    0.38442 (3) obj. -132.815 iterations 3
# Cbc0038I Pass  83: suminf.    0.38236 (3) obj. -132.815 iterations 8
# Cbc0038I Pass  84: suminf.    0.11784 (4) obj. -132.815 iterations 3
# Cbc0038I Pass  85: suminf.    0.29909 (2) obj. -132.815 iterations 5
# Cbc0038I Pass  86: suminf.    0.21053 (2) obj. -133.152 iterations 5
# Cbc0038I Pass  87: suminf.    0.78052 (4) obj. -132.815 iterations 5
# Cbc0038I Pass  88: suminf.    0.11111 (2) obj. -132.951 iterations 4
# Cbc0038I Pass  89: suminf.    0.11111 (2) obj. -132.951 iterations 1
# Cbc0038I Pass  90: suminf.    0.11111 (2) obj. -132.951 iterations 1
# Cbc0038I Pass  91: suminf.    0.85182 (2) obj. -132.815 iterations 5
# Cbc0038I Pass  92: suminf.    0.28342 (2) obj. -132.815 iterations 3
# Cbc0038I Pass  93: suminf.    0.77295 (3) obj. -132.815 iterations 6
# Cbc0038I Pass  94: suminf.    0.97960 (2) obj. -132.815 iterations 4
# Cbc0038I Pass  95: suminf.    0.97960 (2) obj. -132.815 iterations 0
# Cbc0038I Pass  96: suminf.    0.95028 (3) obj. -132.815 iterations 4
# Cbc0038I Pass  97: suminf.    0.38612 (2) obj. -132.815 iterations 7
# Cbc0038I Pass  98: suminf.    0.38612 (2) obj. -132.815 iterations 1
# Cbc0038I Pass  99: suminf.    0.77295 (3) obj. -132.815 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 301 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 314 columns, reduced to 4 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -132.665 - took 0.02 seconds
# Cbc0012I Integer solution of -132.665 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 7 rows 314 columns, reduced to 4 rows 5 columns
# Cbc0012I Integer solution of -132.72 found by DiveCoefficient after 9 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 2 added rows had average density of 13
# Cbc0013I At root node, 2 cuts changed objective from -133.15237 to -132.72 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 13.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 5 row cuts average 12.4 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -132.72, took 9 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 299 variables fixed on reduced cost
# Cuts at root node changed objective from -133.152 to -132.72
# Probing was tried 4 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                132.72000000
# Enumerated nodes:               0
# Total iterations:               9
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# 1

# %%
print("\nTotal points: {}     Total salary: {}\n".format(sum(team[pts_col]), sum(team['salary'])))
team
# Out:
# Total points: 130.63     Total salary: 50000
#                     name  pos  salary  prediction
# 3         Jalen McMillan   WR    3700       10.72
# 6           Kyler Murray   QB    6400       18.66
# 8             Cade Otton   TE    3500        9.99
# 22           Tyreek Hill   WR    7000       19.13
# 27         Jaylen Waddle   WR    5400       13.77
# 29  Los Angeles Chargers  Def    3300        8.23
# 32           Breece Hall   RB    7300       18.49
# 38         De'Von Achane   RB    6200       14.87
# 50        Bijan Robinson   RB    7200       16.77

# %%
print("\nTotal points: {}     Total salary: {}\n".format(sum(team[pts_col]), sum(team['salary'])))
team
# Out:
# Total points: 132.72     Total salary: 50000
#                      name  pos  salary  prediction_df1  prediction_df2  \
# 1                  Bo Nix   QB    5600           16.79            19.3
# 3          Jalen McMillan   WR    3700           10.72            10.4
# 8              Cade Otton   TE    3500            9.99            10.2
# 21            Tyreek Hill   WR    7000           19.13            18.7
# 28   Los Angeles Chargers  Def    3300            8.23             8.5
# 31            Breece Hall   RB    7300           18.49            21.5
# 52            Aaron Jones   RB    6600           14.85            18.5
# 72            Tee Higgins   WR    6500           14.48            15.1
# 156          Tony Pollard   RB    6500           12.16            18.4
#
#      prediction  pred_diff
# 1        18.045       2.51
# 3        10.560       0.32
# 8        10.095       0.21
# 21       18.915       0.43
# 28        8.365       0.27
# 31       19.995       3.01
# 52       16.675       3.65
# 72       14.790       0.62
# 156      15.280       6.24

# %% [markdown]
# ## Save Picks to CSV

# %%
picks_dir = f"{primary_dir}/Weekly Team Picks"
fname = f"{picks_dir}/Adam_week{week}_picks.csv"

# save version in each location
for dir in [my_dir, grp_dir]:
    team[['pos','name','salary']].to_csv(fname, index=False)

# %% [markdown]
# # Optimal Picks per Week

# %%
# salary + scoring
df = df.join(week_df[['name', 'fpts']].set_index('name'), on='name')
df
# Out:
#                  name pos  salary  prediction   fpts
# 0     Patrick Mahomes  QB    8100      25.420  21.34
# 1          Joe Burrow  QB    6300      20.025  14.80
# 2     Trevor Lawrence  QB    6500      20.465  15.74
# 4          Sam Howell  QB    5500      16.570  18.34
# 5        Dak Prescott  QB    6200      18.470    NaN
# ..                ...  ..     ...         ...    ...
# 351    Jason Brownlee  WR    3000       0.225    NaN
# 354    Brandon Bolden  RB    4000       0.365    NaN
# 355       Davis Allen  TE    2500       0.195    NaN
# 356        Mike Boone  RB    4000       0.580   1.10
# 369  Khari Blasingame  RB    4500       0.280   1.10
#
# [312 rows x 5 columns]

# %%
def show_optimal_picks(df, pts_col='fpts', sal_col='salary'):
    week = df.dropna()
    model = PulpSelection(week, pts_col=pts_col)
    team = model.selection
    print("\nTotal points: {}     Total salary: {}\n".format(sum(team[pts_col]), sum(team[sal_col])))
    return team

# %%
show_optimal_picks(df)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/Caskroom/miniconda/base/envs/default/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/cv/pyjmd76x58dbyxrhzycj6c880000gp/T/277c43891ee94cf3b082240ccce60552-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/cv/pyjmd76x58dbyxrhzycj6c880000gp/T/277c43891ee94cf3b082240ccce60552-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 1690 RHS
# At line 1701 BOUNDS
# At line 1952 ENDATA
# Problem MODEL has 10 rows, 250 columns and 947 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 242.62 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 230 columns (230 integer (226 of which binary)) and 690 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -242.62
# Cbc0038I Cleaned solution of -242.62
# Cbc0038I Before mini branch and bound, 230 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -242.62 - took 0.00 seconds
# Cbc0012I Integer solution of -242.62 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -242.62, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -242.62 to -242.62
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                242.62000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 1
#
# Total points: 242.62     Total salary: 54900
#                  name  pos  salary  prediction   fpts
# 11       Drake London   WR    4800      12.345  24.50
# 28         Jared Goff   QB    6400      16.830  25.42
# 63     Raheem Mostert   RB    6400      15.740  37.20
# 67        Cooper Kupp   WR    9000      20.780  30.80
# 69     Kyren Williams   RB    6500      15.255  24.80
# 88        Tyreek Hill   WR    9300      22.715  31.30
# 90       Adam Thielen   WR    5900      13.610  31.50
# 92  Minnesota Vikings  Def    3000       6.075  21.00
# 97     Dalton Schultz   TE    3600       8.195  16.10
