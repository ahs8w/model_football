# %% [markdown]
# ### projection model => project points per player
# - [ ]    Basic Stats
# - [ ]    Usage
# - [ ]    Percentage of team scoring
# - [ ]    Injuries
# - [ ]    Bye week
# - [ ]    Injuries to Key Teammates
# - [ ]    Individual Matchups
# - [ ]    Opposing Team (record, defense, injuries, etc.)
# - [ ]    Home/Away
# - [ ]    Weather
# - [ ]    Expert Picks
# - [x]    Other Fantasy Projections
#
# ### selection mechanism => choose optimal team within parameters
# - [ ]    maximize value (pts/salary)
# - [x]    Linear Optimization
#     - Inspiration: https://github.com/breeko/Fantasy_LP/blob/master/fantasy_lp_final.ipynb

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
year = 2023
week = 14

# %% [markdown]
# # This Week

# %% [markdown]
# ## Rotowire

# %%
# https://www.rotowire.com/daily/nfl/dfs-opportunities.php?site=DraftKings  # choose full slate
def rotowire_csv(filepath):
    df = pd.read_csv(filepath)
    df.rename(columns={'PLAYER': 'name', 'POS': 'pos', 'SAL': 'salary', 'FPTS': 'prediction'}, inplace=True)
    df.loc[df['pos']=='D', 'pos'] = 'Def'
    df = df[['name','pos','salary','prediction']]
    return df
    
rdf = rotowire_csv(f"{year}_fantasy_data/week{week}_rotowire-NFL-projected-roster-percent.csv")
rdf
# Out:
#                     name pos  salary  prediction
# 0          Justin Fields  QB    6800       20.89
# 1    JuJu Smith-Schuster  WR    3000        8.84
# 2         Russell Wilson  QB    5800       16.59
# 3         Desmond Ridder  QB    5000       14.29
# 4         Baker Mayfield  QB    5300       15.17
# ..                   ...  ..     ...         ...
# 579     John FitzPatrick  TE    2500        0.00
# 580     Khari Blasingame  RB    4000        0.10
# 581        Tyler Goodson  RB    4000        0.00
# 582     Christian Watson  WR    4900        0.00
# 583        Nikko Remigio  WR    3000        0.00
#
# [584 rows x 4 columns]

# %%
len(rdf[rdf['pos']=='Def'])
# Out:
# 30

# %% [markdown]
# ## Antonio's Official Data

# %%
sal_dir = f"/Users/adamschiller/OneDrive - BOOZ ALLEN HAMILTON/Weekly Salary Data"
df = pd.read_csv(f"{sal_dir}/week{week}_salaries.csv")

def format_antonio_salary_data(df):
    df.rename(columns={'player': 'name', 'dk_salary': 'salary', 'fantasy_score': 'prediction'}, inplace=True)
    df.loc[df['pos']=='DST', 'pos'] = 'Def'
    df = df[['name','pos','salary','prediction']]
    return df

adf = format_antonio_salary_data(df)
adf
# Out:
#                name pos  salary  prediction
# 0       Zach Wilson  QB    4700       13.50
# 1    Baker Mayfield  QB    5300       15.12
# 2     Justin Fields  QB    6800       19.12
# 3        Geno Smith  QB    5700       15.67
# 4    Desmond Ridder  QB    5000       14.17
# ..              ...  ..     ...         ...
# 566  Trevor Siemian  QB    4700        0.00
# 567     C.J. Uzomah  TE    2500        0.00
# 568   Aaron Rodgers  QB    4000        0.00
# 569  Jesse Matthews  WR    3000        0.00
# 570    Randall Cobb  WR    3000        0.12
#
# [571 rows x 4 columns]

# %%
len(adf[adf['pos']=='Def'])
# Out:
# 30

# %% [markdown]
# ## Daily Fantasy Fuel

# %%
# map defense names for dff based on rotowire names
def defense_mapping(df):
    return {n.split(' ')[-1]: n for n in df[df['pos']=='Def']['name']}

defense_map = defense_mapping(adf)

def apply_defense_map(x):
    try:
        return defense_map[x]
    except KeyError:
        return x

# %%
# https://www.dailyfantasyfuel.com/nfl/projections/
def dff_csv(filepath):
    df = pd.read_csv(filepath)
    df['name'] = df['first_name']+' '+df['last_name']
    df.rename(columns={'position': 'pos', 'ppg_projection': 'prediction'}, inplace=True)
    # fix names for defenses based on mapping created by rotowire data above
    df.loc[df['pos']=='DST', 'name'] = df['first_name'].apply(lambda x: apply_defense_map(x))
    df.loc[df['pos']=='DST', 'pos'] = 'Def'
    df = df[['name','pos','injury_status','salary','prediction']]
    return df

dff = dff_csv(f"{year}_fantasy_data/DFF_NFL_cheatsheet_week{week}.csv")
dff
# Out:
#                     name pos injury_status  salary  prediction
# 0            Tyreek Hill  WR           NaN    9800        25.3
# 1    Christian McCaffrey  RB           NaN    9200        24.6
# 2            Jalen Hurts  QB           NaN    8200        24.4
# 3             Josh Allen  QB           NaN    8300        24.0
# 4           Dak Prescott  QB           NaN    7400        23.8
# ..                   ...  ..           ...     ...         ...
# 399        Isiah Pacheco  RB             O    6700         0.0
# 400     Christian Watson  WR             O    4900         0.0
# 401        Kenny Pickett  QB             O    5000         0.0
# 402       Dalton Schultz  TE             O    5000         0.0
# 403           Josh Whyle  TE             O    2500         0.0
#
# [404 rows x 5 columns]

# %%
len(dff[dff['pos']=='Def'])
# Out:
# 30

# %% [markdown]
# ## Merge sources

# %%
def merge_sources(df1, df2):
    df = df1.merge(df2[['name','injury_status','prediction']], on='name', how='inner', suffixes=('_df1', '_df2'))
    df = df[df['injury_status'].isna()]
    df = df[(df['prediction_df1']>0)&(df['prediction_df2']>0)]
    df['prediction'] = df[['prediction_df1', 'prediction_df2']].mean(axis=1)
    df['pred_diff'] = abs(df['prediction_df1']-df['prediction_df2'])
    df.drop(columns=['injury_status'], inplace=True)  #,'prediction_df1','prediction_df2'
    return df

# %%
df = merge_sources(adf, dff)
df
# Out:
#                  name pos  salary  prediction_df1  prediction_df2  prediction  \
# 0         Zach Wilson  QB    4700           13.50            11.7      12.600
# 1      Baker Mayfield  QB    5300           15.12            15.1      15.110
# 2       Justin Fields  QB    6800           19.12            21.8      20.460
# 4      Desmond Ridder  QB    5000           14.17            13.5      13.835
# 5         Brock Purdy  QB    6500           17.93            20.7      19.315
# ..                ...  ..     ...             ...             ...         ...
# 351       Davis Allen  TE    2700            0.12             0.4       0.260
# 353  Khari Blasingame  RB    4000            0.10             0.1       0.100
# 359  Godwin Igwebuike  RB    4000            0.05             0.1       0.075
# 362      Jalen Nailor  WR    3000            0.13             1.1       0.615
# 374      Randall Cobb  WR    3000            0.12             0.9       0.510
#
#      pred_diff
# 0         1.80
# 1         0.02
# 2         2.68
# 4         0.67
# 5         2.77
# ..         ...
# 351       0.28
# 353       0.00
# 359       0.05
# 362       0.97
# 374       0.78
#
# [310 rows x 7 columns]

# %%
df.sort_values('pred_diff', ascending=False)
# Out:
#                       name pos  salary  prediction_df1  prediction_df2  \
# 280  Clyde Edwards-Helaire  RB    4200            2.28            10.4
# 270          Brevin Jordan  TE    3100            2.26             6.9
# 72                DJ Moore  WR    6500           13.57            18.2
# 100            Tyreek Hill  WR    9800           20.79            25.3
# 80            Keenan Allen  WR    8600           18.20            22.6
# ..                     ...  ..     ...             ...             ...
# 208      Demarcus Robinson  WR    3200            4.09             4.1
# 308         Devin Duvernay  WR    3000            0.90             0.9
# 37          Bijan Robinson  RB    6500           15.30            15.3
# 190          Treylon Burks  WR    3000            4.30             4.3
# 353       Khari Blasingame  RB    4000            0.10             0.1
#
#      prediction  pred_diff
# 280       6.340       8.12
# 270       4.580       4.64
# 72       15.885       4.63
# 100      23.045       4.51
# 80       20.400       4.40
# ..          ...        ...
# 208       4.095       0.01
# 308       0.900       0.00
# 37       15.300       0.00
# 190       4.300       0.00
# 353       0.100       0.00
#
# [310 rows x 7 columns]

# %%
df['pos'].value_counts()
# Out:
# pos
# WR     114
# RB      78
# TE      62
# Def     30
# QB      26
# Name: count, dtype: int64

# %% [markdown]
# # Top Projected per Pos

# %%
def avg_per_dollar(df, col):
    df['Avg Value'] = df[col] / (df['salary'] / 1000)
    return df.sort_values('Avg Value', ascending=False)

pdf = avg_per_dollar(df, 'prediction')

# %%
top_QBs = pdf[pdf.pos=='QB']
top_QBs.head(5)
# Out:
#               name pos  salary  prediction_rdf  prediction_dff  prediction  \
# 82    Joshua Dobbs  QB    5900           15.34            27.5      21.420
# 76   Justin Fields  QB    7000           19.03            29.3      24.165
# 1     Dak Prescott  QB    6800           20.69            22.5      21.595
# 0      Brock Purdy  QB    6100           18.51            19.0      18.755
# 70  Baker Mayfield  QB    5500           16.15            16.3      16.225
#
#     pred_diff  Avg Value
# 82      12.16   3.630508
# 76      10.27   3.452143
# 1        1.81   3.175735
# 0        0.49   3.074590
# 70       0.15   2.950000

# %%
top_RBs = pdf[pdf.pos=='RB']
top_RBs.head(5)
# Out:
#                     name pos  salary  prediction_rdf  prediction_dff  \
# 2        Zach Charbonnet  RB    5300           14.81            14.0
# 9    Christian McCaffrey  RB    8700           20.70            23.6
# 8           Tony Pollard  RB    6700           16.36            16.3
# 103        Rachaad White  RB    6100           13.99            15.7
# 197       Khalil Herbert  RB    5100            9.54            14.8
#
#      prediction  pred_diff  Avg Value
# 2        14.405       0.81   2.717925
# 9        22.150       2.90   2.545977
# 8        16.330       0.06   2.437313
# 103      14.845       1.71   2.433607
# 197      12.170       5.26   2.386275

# %%
top_WRs = pdf[pdf.pos=='WR']
top_WRs.head(5)
# Out:
#                name pos  salary  prediction_rdf  prediction_dff  prediction  \
# 126        DJ Moore  WR    6000           13.34            21.1       17.22
# 81     Drake London  WR    5000           12.82            13.1       12.96
# 79   Rashid Shaheed  WR    4300           11.38            10.7       11.04
# 145  Jordan Addison  WR    5700           11.80            16.8       14.30
# 18      CeeDee Lamb  WR    8700           19.44            23.5       21.47
#
#      pred_diff  Avg Value
# 126       7.76   2.870000
# 81        0.28   2.592000
# 79        0.68   2.567442
# 145       5.00   2.508772
# 18        4.06   2.467816

# %%
top_TEs = pdf[pdf.pos=='TE']
top_TEs.head(5)
# Out:
#                name pos  salary  prediction_rdf  prediction_dff  prediction  \
# 7     Jake Ferguson  TE    3900            9.69            10.9      10.295
# 85      Evan Engram  TE    4200           10.66            11.1      10.880
# 102  T.J. Hockenson  TE    5800           13.45            14.5      13.975
# 14     Logan Thomas  TE    3500            7.99             8.2       8.095
# 164    Trey McBride  TE    4700            9.24            12.4      10.820
#
#      pred_diff  Avg Value
# 7         1.21   2.639744
# 85        0.44   2.590476
# 102       1.05   2.409483
# 14        0.21   2.312857
# 164       3.16   2.302128

# %%
# players[players.Pos == 'Def'].head(3)
top_Defs = pdf[pdf.pos=='Def']
top_Defs.head(5)
# Out:
#                      name  pos  salary  prediction_rdf  prediction_dff  \
# 83     Kansas City Chiefs  Def    3100            8.18             8.7
# 115        Miami Dolphins  Def    3500            8.01             9.7
# 99         Denver Broncos  Def    3200            7.72             8.4
# 95      Minnesota Vikings  Def    3200            7.67             7.8
# 92   New England Patriots  Def    3200            7.61             7.7
#
#      prediction  pred_diff  Avg Value
# 83        8.440       0.52   2.722581
# 115       8.855       1.69   2.530000
# 99        8.060       0.68   2.518750
# 95        7.735       0.13   2.417187
# 92        7.655       0.09   2.392187

# %% [markdown]
# # Team Selection

# %% [markdown]
# $$\begin{aligned}
# objective &= maximize\ team\ points \\
# team\ salary &\leq salary\ cap \\
# team &= 1\ QB + (2|3)\ RB + (3|4)\ WR + (1|2)\ TE + 1\ DEF \\
# team &\leq 9\ total\ players \\
# \end{aligned}$$

# %%
# %pip install pulp

# %%
from pulp import *

class PulpSelection():
    def __init__(self, df, pts_col="prediction", sal_col="salary", name_col="name", salary_cap=50000):
        self.df = df
        self.vars = self.populate_vars(pts_col, sal_col, name_col)
        self.model = self.optimize(salary_cap)
        self.players = self.player_names()
        self.selection = self.selection_df()
        
    def populate_vars(self, pts_col, sal_col, name_col):
        df = self.df
        salaries = {}
        points = {}
        for pos in df.pos.unique():
            available_pos = df[df.pos == pos]
            salary = list(available_pos[[name_col,sal_col]].set_index(name_col).to_dict().values())[0]
            point = list(available_pos[[name_col,pts_col]].set_index(name_col).to_dict().values())[0]
            salaries[pos] = salary
            points[pos] = point
            
        self.salaries = salaries
        self.points = points
        return {k: LpVariable.dict(k, v, cat="Binary") for k, v in points.items()}

    def player_names(self):
        players = {}
        for d in self.vars.values():
            for k,v in d.items():
                players[v] = k
        return players
            
    pos_num_available = {
        "QB": 1,
        "RB": 2,
        "WR": 3,
        "TE": 1,
        "Def": 1
    }

    def optimize(self, salary_cap):
        prob = LpProblem("FFModel", LpMaximize)
        rewards = []
        costs = []

        for pos, players in self.vars.items():
            costs += lpSum([self.salaries[pos][i] * self.vars[pos][i] for i in players])
            rewards += lpSum([self.points[pos][i] * self.vars[pos][i] for i in players])
            if pos in ['RB','WR','TE']:
                prob += lpSum([self.vars[pos][i] for i in players]) <= self.pos_num_available[pos]+1
                prob += lpSum([self.vars[pos][i] for i in players]) >= self.pos_num_available[pos]
            else:
                prob += lpSum([self.vars[pos][i] for i in players]) == self.pos_num_available[pos]
        prob += lpSum(prob.variables()) == 9    # flex -> max of 9 total players

        prob += lpSum(rewards)
        prob += lpSum(costs) <= salary_cap
        print(prob.solve())
        return prob
    
    def selection_df(self):
        selections = [self.players[p] for p in self.model.variables() if p.varValue > 0]
        team = self.df[self.df.name.isin(selections)]
        return team

# %%
# 2023 version
pts_col = 'prediction'
model = PulpSelection(df, pts_col=pts_col)
team = model.selection
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/Caskroom/miniconda/base/envs/default/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/cv/pyjmd76x58dbyxrhzycj6c880000gp/T/ef4a2e03b46e4f6fa2cdb09b6d966e93-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/cv/pyjmd76x58dbyxrhzycj6c880000gp/T/ef4a2e03b46e4f6fa2cdb09b6d966e93-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 2130 RHS
# At line 2141 BOUNDS
# At line 2452 ENDATA
# Problem MODEL has 10 rows, 310 columns and 1184 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 128.105 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 294 columns (294 integer (293 of which binary)) and 882 elements
# Cutoff increment increased from 1e-05 to 0.004995
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.290909
# Cbc0038I Solution found of -126.125
# Cbc0038I Cleaned solution of -126.125
# Cbc0038I Before mini branch and bound, 292 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 294 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -126.327
# Cbc0038I Reduced cost fixing fixed 218 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.02772 (2) obj. -126.327 iterations 3
# Cbc0038I Pass   2: suminf.    0.33333 (2) obj. -127.143 iterations 5
# Cbc0038I Pass   3: suminf.    0.23329 (2) obj. -126.327 iterations 4
# Cbc0038I Pass   4: suminf.    0.48368 (3) obj. -126.327 iterations 9
# Cbc0038I Pass   5: suminf.    0.30390 (2) obj. -126.327 iterations 3
# Cbc0038I Pass   6: suminf.    1.23240 (4) obj. -126.327 iterations 5
# Cbc0038I Pass   7: suminf.    1.23240 (4) obj. -126.327 iterations 1
# Cbc0038I Solution found of -126.575
# Cbc0038I Cleaned solution of -126.575
# Cbc0038I Before mini branch and bound, 283 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 294 columns, reduced to 4 rows 10 columns
# Cbc0038I Mini branch and bound improved solution from -126.575 to -127.5 (0.01 seconds)
# Cbc0038I Round again with cutoff of -127.625
# Cbc0038I Reduced cost fixing fixed 277 variables on major pass 3
# Cbc0038I Pass   8: suminf.    0.22041 (2) obj. -127.625 iterations 1
# Cbc0038I Pass   9: suminf.    0.29091 (2) obj. -128.105 iterations 3
# Cbc0038I Pass  10: suminf.    0.09756 (2) obj. -127.988 iterations 3
# Cbc0038I Pass  11: suminf.    0.02042 (2) obj. -127.625 iterations 3
# Cbc0038I Pass  12: suminf.    0.80000 (2) obj. -127.856 iterations 5
# Cbc0038I Pass  13: suminf.    0.02042 (2) obj. -127.625 iterations 3
# Cbc0038I Pass  14: suminf.    0.88156 (3) obj. -127.625 iterations 6
# Cbc0038I Pass  15: suminf.    0.90667 (2) obj. -127.625 iterations 2
# Cbc0038I Pass  16: suminf.    0.90667 (2) obj. -127.625 iterations 1
# Cbc0038I Pass  17: suminf.    0.96429 (2) obj. -127.667 iterations 3
# Cbc0038I Pass  18: suminf.    0.95834 (2) obj. -127.625 iterations 1
# Cbc0038I Pass  19: suminf.    0.95834 (2) obj. -127.625 iterations 0
# Cbc0038I Pass  20: suminf.    0.65918 (4) obj. -127.625 iterations 5
# Cbc0038I Pass  21: suminf.    0.08963 (2) obj. -127.625 iterations 3
# Cbc0038I Pass  22: suminf.    0.10909 (2) obj. -127.757 iterations 2
# Cbc0038I Pass  23: suminf.    0.87064 (3) obj. -127.625 iterations 4
# Cbc0038I Pass  24: suminf.    0.81410 (4) obj. -127.625 iterations 3
# Cbc0038I Pass  25: suminf.    0.73909 (4) obj. -127.625 iterations 1
# Cbc0038I Pass  26: suminf.    0.87064 (3) obj. -127.625 iterations 2
# Cbc0038I Pass  27: suminf.    1.44168 (4) obj. -127.625 iterations 4
# Cbc0038I Pass  28: suminf.    0.88156 (3) obj. -127.625 iterations 2
# Cbc0038I Pass  29: suminf.    0.90667 (2) obj. -127.625 iterations 3
# Cbc0038I Pass  30: suminf.    0.90667 (2) obj. -127.625 iterations 1
# Cbc0038I Pass  31: suminf.    0.96429 (2) obj. -127.667 iterations 4
# Cbc0038I Pass  32: suminf.    0.95834 (2) obj. -127.625 iterations 2
# Cbc0038I Pass  33: suminf.    0.30189 (4) obj. -127.625 iterations 7
# Cbc0038I Pass  34: suminf.    0.24783 (3) obj. -127.625 iterations 1
# Cbc0038I Pass  35: suminf.    0.11111 (2) obj. -127.946 iterations 2
# Cbc0038I Pass  36: suminf.    0.02203 (2) obj. -127.625 iterations 2
# Cbc0038I Pass  37: suminf.    0.07273 (2) obj. -127.97 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 281 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 7 rows 294 columns, reduced to 5 rows 12 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -127.5 - took 0.01 seconds
# Cbc0012I Integer solution of -127.5 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0012I Integer solution of -127.615 found by DiveCoefficient after 72 iterations and 0 nodes (0.22 seconds)
# Cbc0031I 6 added rows had average density of 16.666667
# Cbc0013I At root node, 6 cuts changed objective from -128.10464 to -127.74529 in 16 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 28 row cuts average 17.4 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 13 row cuts average 16.9 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 54 row cuts average 17.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 16 row cuts average 294.0 elements, 0 column cuts (0 active)  in 0.121 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -127.615 best solution, best possible -127.74529 (0.22 seconds)
# Cbc0001I Search completed - best objective -127.615, took 98 iterations and 4 nodes (0.22 seconds)
# Cbc0032I Strong branching done 40 times (129 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 1, 290 variables fixed on reduced cost
# Cuts at root node changed objective from -128.105 to -127.745
# Probing was tried 22 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 16 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 20 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Clique was tried 16 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 20 times and created 16 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 16 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 16 times and created 54 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 16 times and created 16 cuts of which 0 were active after adding rounds of cuts (0.121 seconds)
#
# Result - Optimal solution found
#
# Objective value:                127.61500000
# Enumerated nodes:               4
# Total iterations:               98
# Time (CPU seconds):             0.15
# Time (Wallclock seconds):       0.22
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.15   (Wallclock seconds):       0.23
#
# 1

# %%
print("\nTotal points: {}     Total salary: {}\n".format(sum(team[pts_col]), sum(team['salary'])))
team
# Out:
# Total points: 127.61500000000002     Total salary: 49900
#                    name  pos  salary  prediction_df1  prediction_df2  \
# 2         Justin Fields   QB    6800           19.12            21.8
# 14       Jonathan Mingo   WR    3500            8.97             7.9
# 23      Ezekiel Elliott   RB    5400           13.33            13.8
# 24         Drake London   WR    4600           11.50            12.2
# 30      Atlanta Falcons  Def    2900            6.99             7.3
# 31   Jaxon Smith-Njigba   WR    4100           10.02             9.6
# 33  Christian McCaffrey   RB    9200           22.43            24.6
# 41        Jake Ferguson   TE    4400           10.28            11.3
# 44          CeeDee Lamb   WR    9000           20.59            23.5
#
#     prediction  pred_diff
# 2       20.460       2.68
# 14       8.435       1.07
# 23      13.565       0.47
# 24      11.850       0.70
# 30       7.145       0.31
# 31       9.810       0.42
# 33      23.515       2.17
# 41      10.790       1.02
# 44      22.045       2.91

# %% [markdown]
# ## Save Picks to CSV

# %%
my_dir = f"{year}_weekly_picks/"
grp_dir = f"/Users/adamschiller/OneDrive - BOOZ ALLEN HAMILTON/Weekly Team Picks/Week {format(week, '02d')}/"
fname = f"Adam_week{week}_picks.csv"

# save version in each location
for dir in [my_dir, grp_dir]:
    team[['pos','name','salary']].to_csv(dir+fname, index=False)

# %% [markdown]
# # Optimal Picks per Week

# %%
# salary + scoring
df = df.join(week_df[['name', 'fpts']].set_index('name'), on='name')
df
# Out:
#                  name pos  salary  prediction   fpts
# 0     Patrick Mahomes  QB    8100      25.420  21.34
# 1          Joe Burrow  QB    6300      20.025  14.80
# 2     Trevor Lawrence  QB    6500      20.465  15.74
# 4          Sam Howell  QB    5500      16.570  18.34
# 5        Dak Prescott  QB    6200      18.470    NaN
# ..                ...  ..     ...         ...    ...
# 351    Jason Brownlee  WR    3000       0.225    NaN
# 354    Brandon Bolden  RB    4000       0.365    NaN
# 355       Davis Allen  TE    2500       0.195    NaN
# 356        Mike Boone  RB    4000       0.580   1.10
# 369  Khari Blasingame  RB    4500       0.280   1.10
#
# [312 rows x 5 columns]

# %%
def show_optimal_picks(df, pts_col='fpts', sal_col='salary'):
    week = df.dropna()
    model = PulpSelection(week, pts_col=pts_col)
    team = model.selection
    print("\nTotal points: {}     Total salary: {}\n".format(sum(team[pts_col]), sum(team[sal_col])))
    return team

# %%
show_optimal_picks(df)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/Caskroom/miniconda/base/envs/default/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/cv/pyjmd76x58dbyxrhzycj6c880000gp/T/277c43891ee94cf3b082240ccce60552-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/cv/pyjmd76x58dbyxrhzycj6c880000gp/T/277c43891ee94cf3b082240ccce60552-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 1690 RHS
# At line 1701 BOUNDS
# At line 1952 ENDATA
# Problem MODEL has 10 rows, 250 columns and 947 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 242.62 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 230 columns (230 integer (226 of which binary)) and 690 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -242.62
# Cbc0038I Cleaned solution of -242.62
# Cbc0038I Before mini branch and bound, 230 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -242.62 - took 0.00 seconds
# Cbc0012I Integer solution of -242.62 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -242.62, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -242.62 to -242.62
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                242.62000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 1
#
# Total points: 242.62     Total salary: 54900
#                  name  pos  salary  prediction   fpts
# 11       Drake London   WR    4800      12.345  24.50
# 28         Jared Goff   QB    6400      16.830  25.42
# 63     Raheem Mostert   RB    6400      15.740  37.20
# 67        Cooper Kupp   WR    9000      20.780  30.80
# 69     Kyren Williams   RB    6500      15.255  24.80
# 88        Tyreek Hill   WR    9300      22.715  31.30
# 90       Adam Thielen   WR    5900      13.610  31.50
# 92  Minnesota Vikings  Def    3000       6.075  21.00
# 97     Dalton Schultz   TE    3600       8.195  16.10
